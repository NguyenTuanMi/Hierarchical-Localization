# %%
# %load_ext autoreload
# %autoreload 2

from pathlib import Path
from pprint import pformat

from hloc import (
    extract_features,
    match_features,
    pairs_from_covisibility,
    pairs_from_retrieval,
)
from hloc import colmap_from_nvm, triangulation, localize_sfm, visualization

# %%
import os
proxy = "http://10.77.8.70:8080/"
os.environ['http_proxy'] = proxy
os.environ['https_proxy'] = proxy
os.environ['HTTP_PROXY'] = proxy
os.environ['HTTPS_PROXY'] = proxy
print("Proxies configured.")
# Out:
# Proxies configured.

# %% [markdown]
# # Pipeline for outdoor day-night visual localization

# %% [markdown]
# ## Setup
# Here we declare the paths to the dataset, the reconstruction and localization outputs, and we choose the feature extractor and the matcher. You only need to download the [Aachen Day-Night dataset](https://www.visuallocalization.net/datasets/) and put it in `datasets/aachen/`, or change the path.

# %%
dataset = Path("datasets/aachen/")  # change this if your dataset is somewhere else
images = dataset / "images_upright/"

outputs = Path("outputs/aachen/")  # where everything will be saved
sfm_pairs = outputs / "pairs-db-covis20.txt"  # top 20 most covisible in SIFT model
loc_pairs = outputs / "pairs-query-netvlad20.txt"  # top 20 retrieved by NetVLAD
reference_sfm = outputs / "sfm_sift"  # the SfM model we will build
results = outputs / "Aachen_hloc_orb.txt"  # the result file

# list the standard configurations available
print(f"Configs for feature extractors:\n{pformat(extract_features.confs)}")
print(f"Configs for feature matchers:\n{pformat(match_features.confs)}")
# Out:
# Configs for feature extractors:
# {'aliked-n16': {'model': {'model_name': 'aliked-n16', 'name': 'aliked'},
#                 'output': 'feats-aliked-n16',
#                 'preprocessing': {'grayscale': False, 'resize_max': 1024}},
#  'd2net-ss': {'model': {'multiscale': False, 'name': 'd2net'},
#               'output': 'feats-d2net-ss',
#               'preprocessing': {'grayscale': False, 'resize_max': 1600}},
#  'dir': {'model': {'name': 'dir'},
#          'output': 'global-feats-dir',
#          'preprocessing': {'resize_max': 1024}},
#  'disk': {'model': {'max_keypoints': 5000, 'name': 'disk'},
#           'output': 'feats-disk',
#           'preprocessing': {'grayscale': False, 'resize_max': 1600}},
#  'megaloc': {'model': {'name': 'megaloc'},
#              'output': 'global-feats-megaloc',
#              'preprocessing': {'resize_max': 1024}},
#  'netvlad': {'model': {'name': 'netvlad'},
#              'output': 'global-feats-netvlad',
#              'preprocessing': {'resize_max': 1024}},
#  'openibl': {'model': {'name': 'openibl'},
#              'output': 'global-feats-openibl',
#              'preprocessing': {'resize_max': 1024}},
#  'orb': {'model': {'name': 'orb'},
#          'output': 'feats-orb',
#          'preprocessing': {'grayscale': True, 'resize_max': 1600}},
#  'r2d2': {'model': {'max_keypoints': 5000, 'name': 'r2d2'},
#           'output': 'feats-r2d2-n5000-r1024',
#           'preprocessing': {'grayscale': False, 'resize_max': 1024}},
#  'sift': {'model': {'name': 'dog'},
#           'output': 'feats-sift',
#           'preprocessing': {'grayscale': True, 'resize_max': 1600}},
#  'sosnet': {'model': {'descriptor': 'sosnet', 'name': 'dog'},
#             'output': 'feats-sosnet',
#             'preprocessing': {'grayscale': True, 'resize_max': 1600}},
#  'superpoint_aachen': {'model': {'max_keypoints': 4096,
#                                  'name': 'superpoint',
#                                  'nms_radius': 3},
#                        'output': 'feats-superpoint-n4096-r1024',
#                        'preprocessing': {'grayscale': True,
#                                          'resize_max': 1024}},
#  'superpoint_inloc': {'model': {'max_keypoints': 4096,
#                                 'name': 'superpoint',
#                                 'nms_radius': 4},
#                       'output': 'feats-superpoint-n4096-r1600',
#                       'preprocessing': {'grayscale': True, 'resize_max': 1600}},
#  'superpoint_max': {'model': {'max_keypoints': 4096,
#                               'name': 'superpoint',
#                               'nms_radius': 3},
#                     'output': 'feats-superpoint-n4096-rmax1600',
#                     'preprocessing': {'grayscale': True,
#                                       'resize_force': True,
#                                       'resize_max': 1600}}}
# Configs for feature matchers:
# {'NN-mutual': {'model': {'do_mutual_check': True, 'name': 'nearest_neighbor'},
#                'output': 'matches-NN-mutual'},
#  'NN-ratio': {'model': {'do_mutual_check': True,
#                         'name': 'nearest_neighbor',
#                         'ratio_threshold': 0.8},
#               'output': 'matches-NN-mutual-ratio.8'},
#  'NN-superpoint': {'model': {'distance_threshold': 0.7,
#                              'do_mutual_check': True,
#                              'name': 'nearest_neighbor'},
#                    'output': 'matches-NN-mutual-dist.7'},
#  'adalam': {'model': {'name': 'adalam'}, 'output': 'matches-adalam'},
#  'aliked+lightglue': {'model': {'features': 'aliked', 'name': 'lightglue'},
#                       'output': 'matches-aliked-lightglue'},
#  'disk+lightglue': {'model': {'features': 'disk', 'name': 'lightglue'},
#                     'output': 'matches-disk-lightglue'},
#  'orb': {'model': {'do_mutual_check': True, 'name': 'orb_match'},
#          'output': 'matches-orb'},
#  'superglue': {'model': {'name': 'superglue',
#                          'sinkhorn_iterations': 50,
#                          'weights': 'outdoor'},
#                'output': 'matches-superglue'},
#  'superglue-fast': {'model': {'name': 'superglue',
#                               'sinkhorn_iterations': 5,
#                               'weights': 'outdoor'},
#                     'output': 'matches-superglue-it5'},
#  'superpoint+lightglue': {'model': {'features': 'superpoint',
#                                     'name': 'lightglue'},
#                           'output': 'matches-superpoint-lightglue'}}

# %%
# pick one of the configurations for image retrieval, local feature extraction, and matching
# you can also simply write your own here!
retrieval_conf = extract_features.confs["netvlad"]
feature_conf = extract_features.confs["sift"]
matcher_conf = match_features.confs["orb"]

# %% [markdown]
# ## Extract local features for database and query images

# %%
features = extract_features.main(feature_conf, images, outputs)
# Out:
# [2026/06/03 10:37:58 hloc INFO] Extracting local features with configuration:
# {'model': {'name': 'dog'},
#  'output': 'feats-sift',
#  'preprocessing': {'grayscale': True, 'resize_max': 1600}}
# [2026/06/03 10:37:58 hloc INFO] Found 5426 images in root datasets/aachen/images_upright.
#   0%|          | 0/5426 [00:00<?, ?it/s]I20260603 10:37:59.086758 135164180387648 sift.cc:763] Creating SIFT CPU feature extractor
# 100%|██████████| 5426/5426 [35:03<00:00,  2.58it/s]
# [2026/06/03 11:13:02 hloc INFO] Finished exporting features.

# %% [markdown]
# The function returns the path of the file in which all the extracted features are stored.

# %% [markdown]
# ## Generate pairs for the SfM reconstruction
# Instead of matching all database images exhaustively, we exploit the existing SIFT model to find which image pairs are the most covisible. We first convert the SIFT model from the NVM to the COLMAP format, and then do a covisiblity search, selecting the top 20 most covisibile neighbors for each image.

# %%
sift_sfm = outputs / "sfm_sift"

pairs_from_covisibility.main(sift_sfm, sfm_pairs, num_matched=20)
# Out:
# [2026/06/03 11:13:02 hloc INFO] Reading the COLMAP model...
# [2026/06/03 11:13:18 hloc INFO] Extracting image pairs from covisibility info...
# 100%|██████████| 4328/4328 [00:28<00:00, 149.52it/s]
# [2026/06/03 11:13:47 hloc INFO] Found 85515 pairs.

# %% [markdown]
# ## Match the database images

# %%
sfm_matches = match_features.main(
    matcher_conf, sfm_pairs, feature_conf["output"], outputs
)
# Out:
# [2026/06/03 11:13:48 hloc INFO] Matching local features with configuration:
# {'model': {'do_mutual_check': True, 'name': 'orb_match'},
#  'output': 'matches-orb'}
# 100%|██████████| 56734/56734 [30:25<00:00, 31.08it/s]
# [2026/06/03 11:44:14 hloc INFO] Finished exporting matches.

# %% [markdown]
# The function returns the path of the file in which all the computed matches are stored.

# %% [markdown]
# ## Triangulate a new SfM model from the given poses
# We triangulate the sparse 3D pointcloud given the matches and the reference poses stored in the SIFT COLMAP model.

# %%
reconstruction = triangulation.main(
    reference_sfm, sift_sfm, images, sfm_pairs, features, sfm_matches
)
# Out:
# [2026/06/03 11:44:17 hloc INFO] Importing features into the database...
# 100%|██████████| 4328/4328 [00:02<00:00, 1975.48it/s]
# [2026/06/03 11:44:19 hloc INFO] Importing matches into the database...
# 100%|██████████| 85515/85515 [00:35<00:00, 2435.40it/s]
# [2026/06/03 11:44:54 hloc INFO] Performing geometric verification of the matches...
# 100%|██████████| 4328/4328 [05:07<00:00, 14.06it/s]
# [2026/06/03 11:50:02 hloc INFO] mean/med/min/max valid matches 0.24/0.18/0.00/2.76%.
# [2026/06/03 11:50:02 hloc INFO] Running 3D triangulation...
# [2026/06/03 11:52:56 hloc INFO] Finished the triangulation with statistics:
# Reconstruction:
# 	num_rigs = 4328
# 	num_cameras = 4328
# 	num_frames = 4328
# 	num_reg_frames = 4328
# 	num_images = 4328
# 	num_points3D = 2145
# 	num_observations = 6164
# 	mean_track_length = 2.87366
# 	mean_observations_per_image = 1.42421
# 	mean_reprojection_error = 1.2441

# %% [markdown]
# ## Find image pairs via image retrieval
# We extract global descriptors with NetVLAD and find for each image the $k$ most similar ones. A larger $k$ improves the robustness of the localization for difficult queries but makes the matching more expensive. Using $k{=}10{-}20$ is generally a good tradeoff but $k{=}50$ gives the best results for the Aachen Day-Night dataset.

# %%
global_descriptors = extract_features.main(retrieval_conf, images, outputs)
pairs_from_retrieval.main(
    global_descriptors, loc_pairs, num_matched=20, db_prefix="db", query_prefix="query"
)
# Out:
# [2026/06/03 11:52:56 hloc INFO] Extracting local features with configuration:
# {'model': {'name': 'netvlad'},
#  'output': 'global-feats-netvlad',
#  'preprocessing': {'resize_max': 1024}}
# [2026/06/03 11:52:56 hloc INFO] Found 5426 images in root datasets/aachen/images_upright.
# [2026/06/03 11:52:57 hloc INFO] Skipping the extraction.
# [2026/06/03 11:52:57 hloc INFO] Extracting image pairs from a retrieval database.
# [2026/06/03 11:52:59 hloc INFO] Found 18940 pairs.

# %% [markdown]
# ## Match the query images

# %%
loc_matches = match_features.main(
    matcher_conf, loc_pairs, feature_conf["output"], outputs
)
# Out:
# [2026/06/03 11:53:00 hloc INFO] Matching local features with configuration:
# {'model': {'do_mutual_check': True, 'name': 'orb_match'},
#  'output': 'matches-orb'}
# 100%|██████████| 18940/18940 [08:35<00:00, 36.73it/s]
# [2026/06/03 12:01:35 hloc INFO] Finished exporting matches.

# %% [markdown]
# ## Localize!
# Perform hierarchical localization using the precomputed retrieval and matches. The file `Aachen_hloc_superpoint+superglue_netvlad50.txt` will contain the estimated query poses. Have a look at `Aachen_hloc_superpoint+superglue_netvlad50.txt_logs.pkl` to analyze some statistics and find failure cases.

# %%
localize_sfm.main(
    reconstruction,
    dataset / "queries/*_time_queries_with_intrinsics.txt",
    loc_pairs,
    features,
    loc_matches,
    results,
    covisibility_clustering=False,
)  # not required with SuperPoint+SuperGlue
# Out:
# [2026/06/03 12:01:35 hloc.utils.parsers INFO] Imported 98 images from night_time_queries_with_intrinsics.txt
# [2026/06/03 12:01:35 hloc.utils.parsers INFO] Imported 824 images from day_time_queries_with_intrinsics.txt
# [2026/06/03 12:01:35 hloc INFO] Reading the 3D model...
# [2026/06/03 12:01:35 hloc INFO] Starting localization...
#   2%|▏         | 22/922 [01:07<46:33,  3.10s/it] [2026/06/03 12:02:42 hloc WARNING] Image db/2418.jpg was retrieved but not in database
#   4%|▍         | 39/922 [02:08<1:14:59,  5.10s/it][2026/06/03 12:03:44 hloc WARNING] Image db/2416.jpg was retrieved but not in database
#   6%|▌         | 54/922 [02:56<51:50,  3.58s/it]  [2026/06/03 12:04:32 hloc WARNING] Image db/3945.jpg was retrieved but not in database
#   6%|▌         | 55/922 [02:59<48:32,  3.36s/it][2026/06/03 12:04:35 hloc WARNING] Image db/2625.jpg was retrieved but not in database
#   8%|▊         | 72/922 [03:58<47:50,  3.38s/it]  [2026/06/03 12:05:33 hloc WARNING] Image db/3940.jpg was retrieved but not in database
# [2026/06/03 12:05:33 hloc WARNING] Image db/3807.jpg was retrieved but not in database
#  10%|█         | 95/922 [05:45<1:14:09,  5.38s/it][2026/06/03 12:07:21 hloc WARNING] Image db/3932.jpg was retrieved but not in database
#  10%|█         | 96/922 [05:49<1:06:06,  4.80s/it][2026/06/03 12:07:24 hloc WARNING] Image db/3785.jpg was retrieved but not in database
#  14%|█▍        | 127/922 [07:00<18:55,  1.43s/it] [2026/06/03 12:08:36 hloc WARNING] Image db/2395.jpg was retrieved but not in database
# [2026/06/03 12:08:36 hloc WARNING] Image db/2402.jpg was retrieved but not in database
#  15%|█▍        | 137/922 [07:19<21:19,  1.63s/it][2026/06/03 12:08:55 hloc WARNING] Image db/2420.jpg was retrieved but not in database
# [2026/06/03 12:08:55 hloc WARNING] Image db/2421.jpg was retrieved but not in database
#  21%|██        | 192/922 [09:43<38:57,  3.20s/it][2026/06/03 12:11:19 hloc WARNING] Image db/1382.jpg was retrieved but not in database
#  26%|██▌       | 237/922 [11:26<27:33,  2.41s/it][2026/06/03 12:13:02 hloc WARNING] Image db/2299.jpg was retrieved but not in database
#  26%|██▌       | 238/922 [11:28<24:40,  2.16s/it][2026/06/03 12:13:03 hloc WARNING] Image db/2299.jpg was retrieved but not in database
#  29%|██▉       | 266/922 [12:33<28:38,  2.62s/it][2026/06/03 12:14:09 hloc WARNING] Image db/2299.jpg was retrieved but not in database
#  33%|███▎      | 301/922 [13:56<14:31,  1.40s/it][2026/06/03 12:15:32 hloc WARNING] Image db/2303.jpg was retrieved but not in database
#  33%|███▎      | 307/922 [14:11<26:34,  2.59s/it][2026/06/03 12:15:47 hloc WARNING] Image db/2304.jpg was retrieved but not in database
#  35%|███▌      | 324/922 [14:45<20:14,  2.03s/it][2026/06/03 12:16:20 hloc WARNING] Image db/2367.jpg was retrieved but not in database
#  48%|████▊     | 440/922 [19:28<20:15,  2.52s/it][2026/06/03 12:21:03 hloc WARNING] Image db/2041.jpg was retrieved but not in database
#  50%|█████     | 462/922 [20:42<26:32,  3.46s/it][2026/06/03 12:22:18 hloc WARNING] Image db/1382.jpg was retrieved but not in database
#  51%|█████     | 470/922 [21:06<21:41,  2.88s/it][2026/06/03 12:22:42 hloc WARNING] Image db/2299.jpg was retrieved but not in database
#  52%|█████▏    | 476/922 [21:19<17:27,  2.35s/it][2026/06/03 12:22:55 hloc WARNING] Image db/2304.jpg was retrieved but not in database
# [2026/06/03 12:22:55 hloc WARNING] Image db/2303.jpg was retrieved but not in database
#  62%|██████▏   | 570/922 [24:57<13:28,  2.30s/it][2026/06/03 12:26:33 hloc WARNING] Image db/2221.jpg was retrieved but not in database
# [2026/06/03 12:26:33 hloc WARNING] Image db/2220.jpg was retrieved but not in database
#  74%|███████▍  | 683/922 [29:15<07:21,  1.85s/it][2026/06/03 12:30:50 hloc WARNING] Image db/2416.jpg was retrieved but not in database
#  74%|███████▍  | 686/922 [29:19<06:03,  1.54s/it][2026/06/03 12:30:55 hloc WARNING] Image db/2419.jpg was retrieved but not in database
# [2026/06/03 12:30:55 hloc WARNING] Image db/3780.jpg was retrieved but not in database
#  77%|███████▋  | 707/922 [30:05<07:01,  1.96s/it][2026/06/03 12:31:41 hloc WARNING] Image db/2625.jpg was retrieved but not in database
# [2026/06/03 12:31:41 hloc WARNING] Image db/2626.jpg was retrieved but not in database
#  80%|████████  | 738/922 [31:16<07:13,  2.36s/it][2026/06/03 12:32:52 hloc WARNING] Image db/2395.jpg was retrieved but not in database
# [2026/06/03 12:32:52 hloc WARNING] Image db/2397.jpg was retrieved but not in database
#  82%|████████▏ | 756/922 [31:48<04:25,  1.60s/it][2026/06/03 12:33:24 hloc WARNING] Image db/4034.jpg was retrieved but not in database
#  83%|████████▎ | 764/922 [32:01<04:35,  1.74s/it][2026/06/03 12:33:37 hloc WARNING] Image db/3941.jpg was retrieved but not in database
#  90%|█████████ | 830/922 [34:01<03:58,  2.59s/it][2026/06/03 12:35:37 hloc WARNING] Image db/2304.jpg was retrieved but not in database
# [2026/06/03 12:35:37 hloc WARNING] Image db/2303.jpg was retrieved but not in database
#  92%|█████████▏| 846/922 [34:24<02:15,  1.78s/it][2026/06/03 12:36:00 hloc WARNING] Image db/2041.jpg was retrieved but not in database
#  94%|█████████▎| 864/922 [35:01<02:06,  2.18s/it][2026/06/03 12:36:36 hloc WARNING] Image db/2041.jpg was retrieved but not in database
# 100%|██████████| 922/922 [37:15<00:00,  2.42s/it]
# [2026/06/03 12:38:50 hloc INFO] Localized 922 / 922 images.
# [2026/06/03 12:38:50 hloc INFO] Writing poses to outputs/aachen/Aachen_hloc_orb.txt...
# [2026/06/03 12:38:50 hloc INFO] Writing logs to outputs/aachen/Aachen_hloc_orb.txt_logs.pkl...
# [2026/06/03 12:39:20 hloc INFO] Done!

# %% [markdown]
# ## Visualizing the SfM model
# We visualize some of the database images with their detected keypoints.

# %% [markdown]
# Color the keypoints by track length: red keypoints are observed many times, blue keypoints few.

# %%
visualization.visualize_sfm_2d(reconstruction, images, n=1, color_by="track_length")
# Out:
# /home/ia/anaconda3/envs/hlock/lib/python3.12/site-packages/numpy/_core/fromnumeric.py:3824: RuntimeWarning: Mean of empty slice
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/ia/anaconda3/envs/hlock/lib/python3.12/site-packages/numpy/_core/_methods.py:142: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /home/ia/ros2_ws/Hierarchical-Localization/hloc/visualization.py:44: RuntimeWarning: invalid value encountered in divide
#   color = cm.jet(tl / tl.max()).tolist()

# %% [markdown]
# Color the keypoints by visibility: blue if sucessfully triangulated, red if never matched.

# %%
visualization.visualize_sfm_2d(reconstruction, images, n=1, color_by="visibility")

# %% [markdown]
# Color the keypoints by triangulated depth: red keypoints are far away, blue keypoints are closer.

# %%
visualization.visualize_sfm_2d(reconstruction, images, n=1, color_by="depth")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 visualization.visualize_sfm_2d(reconstruction, images, n=1, color_by="depth")
#
# File ~/ros2_ws/Hierarchical-Localization/hloc/visualization.py:54, in visualize_sfm_2d(reconstruction, image_dir, color_by, selected, n, seed, dpi)
#      47 p3ids = [p.point3D_id for p in image.points2D if p.has_point3D()]
#      48 z = np.array(
#      49     [
#      50         (image.cam_from_world() * reconstruction.points3D[j].xyz)[-1]
#      51         for j in p3ids
#      52     ]
#      53 )
# ---> 54 z -= z.min()
#      55 color = cm.jet(z / np.percentile(z, 99.9))
#      56 text = f"visible: {np.count_nonzero(visible)}/{len(visible)}"
#
# File ~/anaconda3/envs/hlock/lib/python3.12/site-packages/numpy/_core/_methods.py:45, in _amin(a, axis, out, keepdims, initial, where)
#      43 def _amin(a, axis=None, out=None, keepdims=False,
#      44           initial=_NoValue, where=True):
# ---> 45     return umr_minimum(a, axis, None, out, keepdims, initial, where)
#
# ValueError: zero-size array to reduction operation minimum which has no identity

# %% [markdown]
# ## Visualizing the localization
# We parse the localization logs and for each query image plot matches and inliers with a few database images.

# %%
visualization.visualize_loc(
    results, images, reconstruction, n=1, top_k_db=1, prefix="query/night", seed=2
)
