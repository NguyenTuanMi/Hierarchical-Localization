# %%
# %load_ext autoreload
# %autoreload 2

from pathlib import Path
from pprint import pformat

from hloc import (
    extract_features,
    match_features,
    pairs_from_covisibility,
    pairs_from_retrieval,
)
from hloc import colmap_from_nvm, triangulation, localize_sfm, visualization

# %%
import os
proxy = "http://10.77.8.70:8080/"
os.environ['http_proxy'] = proxy
os.environ['https_proxy'] = proxy
os.environ['HTTP_PROXY'] = proxy
os.environ['HTTPS_PROXY'] = proxy
print("Proxies configured.")
# Out:
# Proxies configured.

# %% [markdown]
# # Pipeline for outdoor day-night visual localization

# %% [markdown]
# ## Setup
# Here we declare the paths to the dataset, the reconstruction and localization outputs, and we choose the feature extractor and the matcher. You only need to download the [Aachen Day-Night dataset](https://www.visuallocalization.net/datasets/) and put it in `datasets/aachen/`, or change the path.

# %%
dataset = Path("datasets/aachen/")  # change this if your dataset is somewhere else
images = dataset / "images_upright/"

outputs = Path("outputs/aachen/")  # where everything will be saved
sfm_pairs = outputs / "pairs-db-covis20.txt"  # top 20 most covisible in SIFT model
loc_pairs = outputs / "pairs-query-netvlad20.txt"  # top 20 retrieved by NetVLAD
reference_sfm = outputs / "sfm_orb"  # the SfM model we will build
results = outputs / "Aachen_hloc_orb.txt"  # the result file

# list the standard configurations available
print(f"Configs for feature extractors:\n{pformat(extract_features.confs)}")
print(f"Configs for feature matchers:\n{pformat(match_features.confs)}")
# Out:
# Configs for feature extractors:
# {'aliked-n16': {'model': {'model_name': 'aliked-n16', 'name': 'aliked'},
#                 'output': 'feats-aliked-n16',
#                 'preprocessing': {'grayscale': False, 'resize_max': 1024}},
#  'd2net-ss': {'model': {'multiscale': False, 'name': 'd2net'},
#               'output': 'feats-d2net-ss',
#               'preprocessing': {'grayscale': False, 'resize_max': 1600}},
#  'dir': {'model': {'name': 'dir'},
#          'output': 'global-feats-dir',
#          'preprocessing': {'resize_max': 1024}},
#  'disk': {'model': {'max_keypoints': 5000, 'name': 'disk'},
#           'output': 'feats-disk',
#           'preprocessing': {'grayscale': False, 'resize_max': 1600}},
#  'megaloc': {'model': {'name': 'megaloc'},
#              'output': 'global-feats-megaloc',
#              'preprocessing': {'resize_max': 1024}},
#  'netvlad': {'model': {'name': 'netvlad'},
#              'output': 'global-feats-netvlad',
#              'preprocessing': {'resize_max': 1024}},
#  'openibl': {'model': {'name': 'openibl'},
#              'output': 'global-feats-openibl',
#              'preprocessing': {'resize_max': 1024}},
#  'orb': {'model': {'name': 'orb'},
#          'output': 'feats-orb',
#          'preprocessing': {'grayscale': True, 'resize_max': 1600}},
#  'r2d2': {'model': {'max_keypoints': 5000, 'name': 'r2d2'},
#           'output': 'feats-r2d2-n5000-r1024',
#           'preprocessing': {'grayscale': False, 'resize_max': 1024}},
#  'sift': {'model': {'name': 'dog'},
#           'output': 'feats-sift',
#           'preprocessing': {'grayscale': True, 'resize_max': 1600}},
#  'sosnet': {'model': {'descriptor': 'sosnet', 'name': 'dog'},
#             'output': 'feats-sosnet',
#             'preprocessing': {'grayscale': True, 'resize_max': 1600}},
#  'superpoint_aachen': {'model': {'max_keypoints': 4096,
#                                  'name': 'superpoint',
#                                  'nms_radius': 3},
#                        'output': 'feats-superpoint-n4096-r1024',
#                        'preprocessing': {'grayscale': True,
#                                          'resize_max': 1024}},
#  'superpoint_inloc': {'model': {'max_keypoints': 4096,
#                                 'name': 'superpoint',
#                                 'nms_radius': 4},
#                       'output': 'feats-superpoint-n4096-r1600',
#                       'preprocessing': {'grayscale': True, 'resize_max': 1600}},
#  'superpoint_max': {'model': {'max_keypoints': 4096,
#                               'name': 'superpoint',
#                               'nms_radius': 3},
#                     'output': 'feats-superpoint-n4096-rmax1600',
#                     'preprocessing': {'grayscale': True,
#                                       'resize_force': True,
#                                       'resize_max': 1600}}}
# Configs for feature matchers:
# {'NN-mutual': {'model': {'do_mutual_check': True, 'name': 'nearest_neighbor'},
#                'output': 'matches-NN-mutual'},
#  'NN-ratio': {'model': {'do_mutual_check': True,
#                         'name': 'nearest_neighbor',
#                         'ratio_threshold': 0.8},
#               'output': 'matches-NN-mutual-ratio.8'},
#  'NN-superpoint': {'model': {'distance_threshold': 0.7,
#                              'do_mutual_check': True,
#                              'name': 'nearest_neighbor'},
#                    'output': 'matches-NN-mutual-dist.7'},
#  'adalam': {'model': {'name': 'adalam'}, 'output': 'matches-adalam'},
#  'aliked+lightglue': {'model': {'features': 'aliked', 'name': 'lightglue'},
#                       'output': 'matches-aliked-lightglue'},
#  'disk+lightglue': {'model': {'features': 'disk', 'name': 'lightglue'},
#                     'output': 'matches-disk-lightglue'},
#  'orb': {'model': {'do_mutual_check': True, 'name': 'orb_match'},
#          'output': 'matches-orb'},
#  'superglue': {'model': {'name': 'superglue',
#                          'sinkhorn_iterations': 50,
#                          'weights': 'outdoor'},
#                'output': 'matches-superglue'},
#  'superglue-fast': {'model': {'name': 'superglue',
#                               'sinkhorn_iterations': 5,
#                               'weights': 'outdoor'},
#                     'output': 'matches-superglue-it5'},
#  'superpoint+lightglue': {'model': {'features': 'superpoint',
#                                     'name': 'lightglue'},
#                           'output': 'matches-superpoint-lightglue'}}

# %%
# pick one of the configurations for image retrieval, local feature extraction, and matching
# you can also simply write your own here!
retrieval_conf = extract_features.confs["netvlad"]
feature_conf = extract_features.confs["orb"]
matcher_conf = match_features.confs["orb"]

# %% [markdown]
# ## Extract local features for database and query images

# %%
features = extract_features.main(feature_conf, images, outputs)
# Out:
# [2026/06/02 11:36:46 hloc INFO] Extracting local features with configuration:
# {'model': {'name': 'orb'},
#  'output': 'feats-orb',
#  'preprocessing': {'grayscale': True, 'resize_max': 1600}}
# [2026/06/02 11:36:47 hloc INFO] Found 5426 images in root datasets/aachen/images_upright.
# 100%|██████████| 5426/5426 [03:08<00:00, 28.76it/s]
# [2026/06/02 11:39:55 hloc INFO] Finished exporting features.

# %% [markdown]
# The function returns the path of the file in which all the extracted features are stored.

# %% [markdown]
# ## Generate pairs for the SfM reconstruction
# Instead of matching all database images exhaustively, we exploit the existing SIFT model to find which image pairs are the most covisible. We first convert the SIFT model from the NVM to the COLMAP format, and then do a covisiblity search, selecting the top 20 most covisibile neighbors for each image.

# %%
sift_sfm = outputs / "sfm_sift"

pairs_from_covisibility.main(sift_sfm, sfm_pairs, num_matched=20)
# Out:
# [2026/06/02 11:39:55 hloc INFO] Reading the COLMAP model...
# [2026/06/02 11:40:11 hloc INFO] Extracting image pairs from covisibility info...
# 100%|██████████| 4328/4328 [00:28<00:00, 153.38it/s]
# [2026/06/02 11:40:40 hloc INFO] Found 85515 pairs.

# %% [markdown]
# ## Match the database images

# %%
sfm_matches = match_features.main(
    matcher_conf, sfm_pairs, feature_conf["output"], outputs
)
# Out:
# [2026/06/02 11:40:40 hloc INFO] Matching local features with configuration:
# {'model': {'do_mutual_check': True, 'name': 'orb_match'},
#  'output': 'matches-orb'}
# 100%|██████████| 56734/56734 [31:37<00:00, 29.91it/s]
# [2026/06/02 12:12:17 hloc INFO] Finished exporting matches.

# %% [markdown]
# The function returns the path of the file in which all the computed matches are stored.

# %% [markdown]
# ## Triangulate a new SfM model from the given poses
# We triangulate the sparse 3D pointcloud given the matches and the reference poses stored in the SIFT COLMAP model.

# %%
reconstruction = triangulation.main(
    reference_sfm, sift_sfm, images, sfm_pairs, features, sfm_matches
)
# Out:
# [2026/06/02 12:12:21 hloc INFO] Importing features into the database...
# 100%|██████████| 4328/4328 [00:02<00:00, 1932.17it/s]
# [2026/06/02 12:12:23 hloc INFO] Importing matches into the database...
# 100%|██████████| 85515/85515 [00:35<00:00, 2391.33it/s]
# [2026/06/02 12:12:59 hloc INFO] Performing geometric verification of the matches...
# 100%|██████████| 4328/4328 [05:40<00:00, 12.70it/s]
# [2026/06/02 12:18:40 hloc INFO] mean/med/min/max valid matches 6.82/3.14/0.00/85.68%.
# [2026/06/02 12:18:40 hloc INFO] Running 3D triangulation...
# [2026/06/02 12:23:08 hloc INFO] Finished the triangulation with statistics:
# Reconstruction:
# 	num_rigs = 4328
# 	num_cameras = 4328
# 	num_frames = 4328
# 	num_reg_frames = 4328
# 	num_images = 4328
# 	num_points3D = 1181202
# 	num_observations = 7379271
# 	mean_track_length = 6.24726
# 	mean_observations_per_image = 1705.01
# 	mean_reprojection_error = 1.14698

# %% [markdown]
# ## Find image pairs via image retrieval
# We extract global descriptors with NetVLAD and find for each image the $k$ most similar ones. A larger $k$ improves the robustness of the localization for difficult queries but makes the matching more expensive. Using $k{=}10{-}20$ is generally a good tradeoff but $k{=}50$ gives the best results for the Aachen Day-Night dataset.

# %%
global_descriptors = extract_features.main(retrieval_conf, images, outputs)
pairs_from_retrieval.main(
    global_descriptors, loc_pairs, num_matched=20, db_prefix="db", query_prefix="query"
)
# Out:
# [2026/06/02 12:23:08 hloc INFO] Extracting local features with configuration:
# {'model': {'name': 'netvlad'},
#  'output': 'global-feats-netvlad',
#  'preprocessing': {'resize_max': 1024}}
# [2026/06/02 12:23:09 hloc INFO] Found 5426 images in root datasets/aachen/images_upright.
# [2026/06/02 12:23:09 hloc INFO] Skipping the extraction.
# [2026/06/02 12:23:09 hloc INFO] Extracting image pairs from a retrieval database.
# [2026/06/02 12:23:12 hloc INFO] Found 18940 pairs.

# %% [markdown]
# ## Match the query images

# %%
loc_matches = match_features.main(
    matcher_conf, loc_pairs, feature_conf["output"], outputs
)
# Out:
# [2026/06/02 12:23:12 hloc INFO] Matching local features with configuration:
# {'model': {'do_mutual_check': True, 'name': 'orb_match'},
#  'output': 'matches-orb'}
# 100%|██████████| 18940/18940 [10:57<00:00, 28.80it/s]
# [2026/06/02 12:34:10 hloc INFO] Finished exporting matches.

# %% [markdown]
# ## Localize!
# Perform hierarchical localization using the precomputed retrieval and matches. The file `Aachen_hloc_superpoint+superglue_netvlad50.txt` will contain the estimated query poses. Have a look at `Aachen_hloc_superpoint+superglue_netvlad50.txt_logs.pkl` to analyze some statistics and find failure cases.

# %%
localize_sfm.main(
    reconstruction,
    dataset / "queries/*_time_queries_with_intrinsics.txt",
    loc_pairs,
    features,
    loc_matches,
    results,
    covisibility_clustering=False,
)  # not required with SuperPoint+SuperGlue
# Out:
# [2026/06/02 12:34:10 hloc.utils.parsers INFO] Imported 98 images from night_time_queries_with_intrinsics.txt
# [2026/06/02 12:34:10 hloc.utils.parsers INFO] Imported 824 images from day_time_queries_with_intrinsics.txt
# [2026/06/02 12:34:10 hloc INFO] Reading the 3D model...
# [2026/06/02 12:34:10 hloc INFO] Starting localization...
#   2%|▏         | 22/922 [01:16<49:30,  3.30s/it] [2026/06/02 12:35:26 hloc WARNING] Image db/2418.jpg was retrieved but not in database
#   4%|▍         | 39/922 [02:21<56:20,  3.83s/it]  [2026/06/02 12:36:31 hloc WARNING] Image db/2416.jpg was retrieved but not in database
#   6%|▌         | 54/922 [03:15<52:15,  3.61s/it][2026/06/02 12:37:26 hloc WARNING] Image db/3945.jpg was retrieved but not in database
#   6%|▌         | 55/922 [03:18<47:29,  3.29s/it][2026/06/02 12:37:28 hloc WARNING] Image db/2625.jpg was retrieved but not in database
#   8%|▊         | 72/922 [04:29<53:31,  3.78s/it]  [2026/06/02 12:38:40 hloc WARNING] Image db/3940.jpg was retrieved but not in database
# [2026/06/02 12:38:40 hloc WARNING] Image db/3807.jpg was retrieved but not in database
#  10%|█         | 95/922 [06:04<56:01,  4.06s/it]  [2026/06/02 12:40:14 hloc WARNING] Image db/3932.jpg was retrieved but not in database
#  10%|█         | 96/922 [06:06<49:00,  3.56s/it][2026/06/02 12:40:16 hloc WARNING] Image db/3785.jpg was retrieved but not in database
#  14%|█▍        | 127/922 [08:17<55:52,  4.22s/it]  [2026/06/02 12:42:27 hloc WARNING] Image db/2395.jpg was retrieved but not in database
# [2026/06/02 12:42:27 hloc WARNING] Image db/2402.jpg was retrieved but not in database
#  15%|█▍        | 137/922 [08:56<47:59,  3.67s/it]  [2026/06/02 12:43:06 hloc WARNING] Image db/2420.jpg was retrieved but not in database
# [2026/06/02 12:43:06 hloc WARNING] Image db/2421.jpg was retrieved but not in database
#  21%|██        | 192/922 [12:23<47:34,  3.91s/it]  [2026/06/02 12:46:33 hloc WARNING] Image db/1382.jpg was retrieved but not in database
#  26%|██▌       | 237/922 [15:03<39:18,  3.44s/it][2026/06/02 12:49:14 hloc WARNING] Image db/2299.jpg was retrieved but not in database
#  26%|██▌       | 238/922 [15:06<36:33,  3.21s/it][2026/06/02 12:49:16 hloc WARNING] Image db/2299.jpg was retrieved but not in database
#  29%|██▉       | 266/922 [16:59<42:04,  3.85s/it][2026/06/02 12:51:09 hloc WARNING] Image db/2299.jpg was retrieved but not in database
#  33%|███▎      | 301/922 [19:12<34:24,  3.32s/it][2026/06/02 12:53:22 hloc WARNING] Image db/2303.jpg was retrieved but not in database
#  33%|███▎      | 307/922 [19:32<38:49,  3.79s/it][2026/06/02 12:53:42 hloc WARNING] Image db/2304.jpg was retrieved but not in database
#  35%|███▌      | 324/922 [20:24<31:56,  3.20s/it][2026/06/02 12:54:34 hloc WARNING] Image db/2367.jpg was retrieved but not in database
#  48%|████▊     | 440/922 [27:30<31:21,  3.90s/it][2026/06/02 13:01:41 hloc WARNING] Image db/2041.jpg was retrieved but not in database
#  50%|█████     | 462/922 [28:55<27:27,  3.58s/it][2026/06/02 13:03:05 hloc WARNING] Image db/1382.jpg was retrieved but not in database
#  51%|█████     | 470/922 [29:24<23:46,  3.16s/it][2026/06/02 13:03:34 hloc WARNING] Image db/2299.jpg was retrieved but not in database
#  52%|█████▏    | 476/922 [29:45<27:22,  3.68s/it][2026/06/02 13:03:55 hloc WARNING] Image db/2304.jpg was retrieved but not in database
# [2026/06/02 13:03:55 hloc WARNING] Image db/2303.jpg was retrieved but not in database
#  62%|██████▏   | 570/922 [36:03<19:17,  3.29s/it][2026/06/02 13:10:13 hloc WARNING] Image db/2221.jpg was retrieved but not in database
# [2026/06/02 13:10:13 hloc WARNING] Image db/2220.jpg was retrieved but not in database
#  74%|███████▍  | 683/922 [43:28<15:13,  3.82s/it][2026/06/02 13:17:38 hloc WARNING] Image db/2416.jpg was retrieved but not in database
#  74%|███████▍  | 686/922 [43:40<15:59,  4.07s/it][2026/06/02 13:17:50 hloc WARNING] Image db/2419.jpg was retrieved but not in database
# [2026/06/02 13:17:50 hloc WARNING] Image db/3780.jpg was retrieved but not in database
#  77%|███████▋  | 707/922 [45:00<12:42,  3.55s/it][2026/06/02 13:19:10 hloc WARNING] Image db/2625.jpg was retrieved but not in database
# [2026/06/02 13:19:10 hloc WARNING] Image db/2626.jpg was retrieved but not in database
#  80%|████████  | 738/922 [46:58<12:42,  4.15s/it][2026/06/02 13:21:08 hloc WARNING] Image db/2395.jpg was retrieved but not in database
# [2026/06/02 13:21:08 hloc WARNING] Image db/2397.jpg was retrieved but not in database
#  82%|████████▏ | 756/922 [48:02<09:24,  3.40s/it][2026/06/02 13:22:12 hloc WARNING] Image db/4034.jpg was retrieved but not in database
#  83%|████████▎ | 764/922 [48:28<09:12,  3.50s/it][2026/06/02 13:22:38 hloc WARNING] Image db/3941.jpg was retrieved but not in database
#  90%|█████████ | 830/922 [52:33<04:26,  2.90s/it][2026/06/02 13:26:44 hloc WARNING] Image db/2304.jpg was retrieved but not in database
# [2026/06/02 13:26:44 hloc WARNING] Image db/2303.jpg was retrieved but not in database
#  92%|█████████▏| 846/922 [53:26<04:47,  3.78s/it][2026/06/02 13:27:37 hloc WARNING] Image db/2041.jpg was retrieved but not in database
#  94%|█████████▎| 864/922 [54:39<04:20,  4.49s/it][2026/06/02 13:28:49 hloc WARNING] Image db/2041.jpg was retrieved but not in database
# 100%|██████████| 922/922 [58:28<00:00,  3.80s/it]
# [2026/06/02 13:32:38 hloc INFO] Localized 922 / 922 images.
# [2026/06/02 13:32:38 hloc INFO] Writing poses to outputs/aachen/Aachen_hloc_orb.txt...
# [2026/06/02 13:32:38 hloc INFO] Writing logs to outputs/aachen/Aachen_hloc_orb.txt_logs.pkl...
# [2026/06/02 13:33:54 hloc INFO] Done!

# %% [markdown]
# ## Visualizing the SfM model
# We visualize some of the database images with their detected keypoints.

# %% [markdown]
# Color the keypoints by track length: red keypoints are observed many times, blue keypoints few.

# %%
visualization.visualize_sfm_2d(reconstruction, images, n=1, color_by="track_length")

# %% [markdown]
# Color the keypoints by visibility: blue if sucessfully triangulated, red if never matched.

# %%
visualization.visualize_sfm_2d(reconstruction, images, n=1, color_by="visibility")

# %% [markdown]
# Color the keypoints by triangulated depth: red keypoints are far away, blue keypoints are closer.

# %%
visualization.visualize_sfm_2d(reconstruction, images, n=1, color_by="depth")

# %% [markdown]
# ## Visualizing the localization
# We parse the localization logs and for each query image plot matches and inliers with a few database images.

# %%
visualization.visualize_loc(
    results, images, reconstruction, n=1, top_k_db=1, prefix="query/night", seed=2
)
