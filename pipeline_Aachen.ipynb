# %%
# %load_ext autoreload
# %autoreload 2

from pathlib import Path
from pprint import pformat

from hloc import (
    extract_features,
    match_features,
    pairs_from_covisibility,
    pairs_from_retrieval,
)
from hloc import colmap_from_nvm, triangulation, localize_sfm, visualization

# %% [markdown]
# # Pipeline for outdoor day-night visual localization

# %% [markdown]
# ## Setup
# Here we declare the paths to the dataset, the reconstruction and localization outputs, and we choose the feature extractor and the matcher. You only need to download the [Aachen Day-Night dataset](https://www.visuallocalization.net/datasets/) and put it in `datasets/aachen/`, or change the path.

# %%
dataset = Path("datasets/aachen/")  # change this if your dataset is somewhere else
images = dataset / "images_upright/"

outputs = Path("outputs/aachen/")  # where everything will be saved
sfm_pairs = outputs / "pairs-db-covis20.txt"  # top 20 most covisible in SIFT model
loc_pairs = outputs / "pairs-query-netvlad20.txt"  # top 20 retrieved by NetVLAD
reference_sfm = outputs / "sfm_sfd2+aliked-lightglue"  # the SfM model we will build
results = outputs / "Aachen_hloc_sfd2+aliked-lightglue_netvlad20.txt"  # the result file

# list the standard configurations available
print(f"Configs for feature extractors:\n{pformat(extract_features.confs)}")
print(f"Configs for feature matchers:\n{pformat(match_features.confs)}")
# Out:
# Configs for feature extractors:
# {'aliked-n16': {'model': {'model_name': 'aliked-n16', 'name': 'aliked'},
#                 'output': 'feats-aliked-n16',
#                 'preprocessing': {'grayscale': False, 'resize_max': 1024}},
#  'd2net-ss': {'model': {'multiscale': False, 'name': 'd2net'},
#               'output': 'feats-d2net-ss',
#               'preprocessing': {'grayscale': False, 'resize_max': 1600}},
#  'dir': {'model': {'name': 'dir'},
#          'output': 'global-feats-dir',
#          'preprocessing': {'resize_max': 1024}},
#  'disk': {'model': {'max_keypoints': 5000, 'name': 'disk'},
#           'output': 'feats-disk',
#           'preprocessing': {'grayscale': False, 'resize_max': 1600}},
#  'megaloc': {'model': {'name': 'megaloc'},
#              'output': 'global-feats-megaloc',
#              'preprocessing': {'resize_max': 1024}},
#  'netvlad': {'model': {'name': 'netvlad'},
#              'output': 'global-feats-netvlad',
#              'preprocessing': {'resize_max': 1024}},
#  'openibl': {'model': {'name': 'openibl'},
#              'output': 'global-feats-openibl',
#              'preprocessing': {'resize_max': 1024}},
#  'r2d2': {'model': {'max_keypoints': 5000, 'name': 'r2d2'},
#           'output': 'feats-r2d2-n5000-r1024',
#           'preprocessing': {'grayscale': False, 'resize_max': 1024}},
#  'sfd2': {'model': {'max_keypoints': 4096, 'name': 'sfd2', 'nms_radius': 3},
#           'output': 'feats-sfd2-n4096-r1024',
#           'preprocessing': {'grayscale': False, 'resize_max': 1024}},
#  'sift': {'model': {'name': 'dog'},
#           'output': 'feats-sift',
#           'preprocessing': {'grayscale': True, 'resize_max': 1600}},
#  'sosnet': {'model': {'descriptor': 'sosnet', 'name': 'dog'},
#             'output': 'feats-sosnet',
#             'preprocessing': {'grayscale': True, 'resize_max': 1600}},
#  'superpoint_aachen': {'model': {'max_keypoints': 4096,
#                                  'name': 'superpoint',
#                                  'nms_radius': 3},
#                        'output': 'feats-superpoint-n4096-r1024',
#                        'preprocessing': {'grayscale': True,
#                                          'resize_max': 1024}},
#  'superpoint_inloc': {'model': {'max_keypoints': 4096,
#                                 'name': 'superpoint',
#                                 'nms_radius': 4},
#                       'output': 'feats-superpoint-n4096-r1600',
#                       'preprocessing': {'grayscale': True, 'resize_max': 1600}},
#  'superpoint_max': {'model': {'max_keypoints': 4096,
#                               'name': 'superpoint',
#                               'nms_radius': 3},
#                     'output': 'feats-superpoint-n4096-rmax1600',
#                     'preprocessing': {'grayscale': True,
#                                       'resize_force': True,
#                                       'resize_max': 1600}}}
# Configs for feature matchers:
# {'NN-mutual': {'model': {'do_mutual_check': True, 'name': 'nearest_neighbor'},
#                'output': 'matches-NN-mutual'},
#  'NN-ratio': {'model': {'do_mutual_check': True,
#                         'name': 'nearest_neighbor',
#                         'ratio_threshold': 0.8},
#               'output': 'matches-NN-mutual-ratio.8'},
#  'NN-superpoint': {'model': {'distance_threshold': 0.7,
#                              'do_mutual_check': True,
#                              'name': 'nearest_neighbor'},
#                    'output': 'matches-NN-mutual-dist.7'},
#  'adalam': {'model': {'name': 'adalam'}, 'output': 'matches-adalam'},
#  'aliked+lightglue': {'model': {'features': 'aliked', 'name': 'lightglue'},
#                       'output': 'matches-aliked-lightglue'},
#  'disk+lightglue': {'model': {'features': 'disk', 'name': 'lightglue'},
#                     'output': 'matches-disk-lightglue'},
#  'superglue': {'model': {'name': 'superglue',
#                          'sinkhorn_iterations': 50,
#                          'weights': 'outdoor'},
#                'output': 'matches-superglue'},
#  'superglue-fast': {'model': {'name': 'superglue',
#                               'sinkhorn_iterations': 5,
#                               'weights': 'outdoor'},
#                     'output': 'matches-superglue-it5'},
#  'superpoint+lightglue': {'model': {'features': 'superpoint',
#                                     'name': 'lightglue'},
#                           'output': 'matches-superpoint-lightglue'}}

# %%
# pick one of the configurations for image retrieval, local feature extraction, and matching
# you can also simply write your own here!
retrieval_conf = extract_features.confs["netvlad"]
feature_conf = extract_features.confs["sfd2"]
matcher_conf = match_features.confs["aliked+lightglue"]

# %% [markdown]
# ## Extract local features for database and query images

# %%
features = extract_features.main(feature_conf, images, outputs)
# Out:
# [2026/06/16 19:10:38 hloc INFO] Extracting local features with configuration:
# {'model': {'max_keypoints': 4096, 'name': 'sfd2', 'nms_radius': 3},
#  'output': 'feats-sfd2-n4096-r1024',
#  'preprocessing': {'grayscale': False, 'resize_max': 1024}}
# [2026/06/16 19:10:38 hloc INFO] Found 5426 images in root datasets/aachen/images_upright.
# [2026/06/16 19:10:39 hloc INFO] Skipping the extraction.

# %% [markdown]
# The function returns the path of the file in which all the extracted features are stored.

# %% [markdown]
# ## Generate pairs for the SfM reconstruction
# Instead of matching all database images exhaustively, we exploit the existing SIFT model to find which image pairs are the most covisible. We first convert the SIFT model from the NVM to the COLMAP format, and then do a covisiblity search, selecting the top 20 most covisibile neighbors for each image.

# %%
# colmap_from_nvm.main(
#     dataset / "3D-models/aachen_cvpr2018_db.nvm",
#     dataset / "3D-models/database_intrinsics.txt",
#     dataset / "aachen.db",
#     outputs / "sfm_sift",
# )

# pairs_from_covisibility.main(outputs / "sfm_sift", sfm_pairs, num_matched=20)

# %% [markdown]
# ## Match the database images

# %%
sfm_matches = match_features.main(
    matcher_conf, sfm_pairs, feature_conf["output"], outputs
)
# Out:
# [2026/06/16 19:10:39 hloc INFO] Matching local features with configuration:
# {'model': {'features': 'aliked', 'name': 'lightglue'},
#  'output': 'matches-aliked-lightglue'}
# 100%|██████████| 56734/56734 [14:20<00:00, 65.95it/s]
# [2026/06/16 19:25:01 hloc INFO] Finished exporting matches.

# %% [markdown]
# The function returns the path of the file in which all the computed matches are stored.

# %% [markdown]
# ## Triangulate a new SfM model from the given poses
# We triangulate the sparse 3D pointcloud given the matches and the reference poses stored in the SIFT COLMAP model.

# %%
reconstruction = triangulation.main(
    reference_sfm, outputs / "sfm_sift", images, sfm_pairs, features, sfm_matches
)
# Out:
# [2026/06/16 19:25:04 hloc INFO] Importing features into the database...
# 100%|██████████| 4328/4328 [00:02<00:00, 2097.90it/s]
# [2026/06/16 19:25:06 hloc INFO] Importing matches into the database...
# 100%|██████████| 85515/85515 [00:35<00:00, 2440.62it/s]
# [2026/06/16 19:25:41 hloc INFO] Performing geometric verification of the matches...
# 100%|██████████| 4328/4328 [03:56<00:00, 18.26it/s]
# [2026/06/16 19:29:38 hloc INFO] mean/med/min/max valid matches 66.34/81.20/0.00/100.00%.
# [2026/06/16 19:29:38 hloc INFO] Running 3D triangulation...
# [2026/06/16 19:34:09 hloc INFO] Finished the triangulation with statistics:
# Reconstruction:
# 	num_rigs = 4328
# 	num_cameras = 4328
# 	num_frames = 4328
# 	num_reg_frames = 4328
# 	num_images = 4328
# 	num_points3D = 1413717
# 	num_observations = 7644644
# 	mean_track_length = 5.40748
# 	mean_observations_per_image = 1766.32
# 	mean_reprojection_error = 1.50242

# %% [markdown]
# ## Find image pairs via image retrieval
# We extract global descriptors with NetVLAD and find for each image the $k$ most similar ones. A larger $k$ improves the robustness of the localization for difficult queries but makes the matching more expensive. Using $k{=}10{-}20$ is generally a good tradeoff but $k{=}50$ gives the best results for the Aachen Day-Night dataset.

# %%
global_descriptors = extract_features.main(retrieval_conf, images, outputs)
pairs_from_retrieval.main(
    global_descriptors, loc_pairs, num_matched=20, db_prefix="db", query_prefix="query"
)
# Out:
# [2026/06/16 19:34:09 hloc INFO] Extracting local features with configuration:
# {'model': {'name': 'netvlad'},
#  'output': 'global-feats-netvlad',
#  'preprocessing': {'resize_max': 1024}}
# [2026/06/16 19:34:09 hloc INFO] Found 5426 images in root datasets/aachen/images_upright.
# [2026/06/16 19:34:10 hloc INFO] Skipping the extraction.
# [2026/06/16 19:34:10 hloc INFO] Extracting image pairs from a retrieval database.
# [2026/06/16 19:34:13 hloc INFO] Found 18940 pairs.

# %% [markdown]
# ## Match the query images

# %%
loc_matches = match_features.main(
    matcher_conf, loc_pairs, feature_conf["output"], outputs
)
# Out:
# [2026/06/16 19:34:13 hloc INFO] Matching local features with configuration:
# {'model': {'features': 'aliked', 'name': 'lightglue'},
#  'output': 'matches-aliked-lightglue'}
# 100%|██████████| 18940/18940 [04:28<00:00, 70.53it/s]
# [2026/06/16 19:38:41 hloc INFO] Finished exporting matches.

# %% [markdown]
# ## Localize!
# Perform hierarchical localization using the precomputed retrieval and matches. The file `Aachen_hloc_superpoint+superglue_netvlad50.txt` will contain the estimated query poses. Have a look at `Aachen_hloc_superpoint+superglue_netvlad50.txt_logs.pkl` to analyze some statistics and find failure cases.

# %%
localize_sfm.main(
    reconstruction,
    dataset / "queries/*_time_queries_with_intrinsics.txt",
    loc_pairs,
    features,
    loc_matches,
    results,
    covisibility_clustering=False,
)  # not required with SuperPoint+SuperGlue
# Out:
# [2026/06/16 19:38:41 hloc.utils.parsers INFO] Imported 98 images from night_time_queries_with_intrinsics.txt
# [2026/06/16 19:38:41 hloc.utils.parsers INFO] Imported 824 images from day_time_queries_with_intrinsics.txt
# [2026/06/16 19:38:41 hloc INFO] Reading the 3D model...
# [2026/06/16 19:38:41 hloc INFO] Starting localization...
#   2%|▏         | 22/922 [00:02<01:15, 11.93it/s][2026/06/16 19:38:43 hloc WARNING] Image db/2418.jpg was retrieved but not in database
#   4%|▍         | 38/922 [00:03<01:42,  8.64it/s][2026/06/16 19:38:45 hloc WARNING] Image db/2416.jpg was retrieved but not in database
#   6%|▌         | 54/922 [00:05<01:17, 11.27it/s][2026/06/16 19:38:47 hloc WARNING] Image db/3945.jpg was retrieved but not in database
# [2026/06/16 19:38:47 hloc WARNING] Image db/2625.jpg was retrieved but not in database
#   8%|▊         | 72/922 [00:07<01:24, 10.10it/s][2026/06/16 19:38:48 hloc WARNING] Image db/3940.jpg was retrieved but not in database
# [2026/06/16 19:38:48 hloc WARNING] Image db/3807.jpg was retrieved but not in database
#  10%|█         | 95/922 [00:09<01:25,  9.66it/s][2026/06/16 19:38:51 hloc WARNING] Image db/3932.jpg was retrieved but not in database
# [2026/06/16 19:38:51 hloc WARNING] Image db/3785.jpg was retrieved but not in database
#  14%|█▍        | 127/922 [00:14<01:53,  7.01it/s][2026/06/16 19:38:56 hloc WARNING] Image db/2395.jpg was retrieved but not in database
# [2026/06/16 19:38:56 hloc WARNING] Image db/2402.jpg was retrieved but not in database
#  15%|█▍        | 137/922 [00:16<01:59,  6.55it/s][2026/06/16 19:38:57 hloc WARNING] Image db/2420.jpg was retrieved but not in database
# [2026/06/16 19:38:57 hloc WARNING] Image db/2421.jpg was retrieved but not in database
#  21%|██        | 192/922 [00:23<02:17,  5.30it/s][2026/06/16 19:39:05 hloc WARNING] Image db/1382.jpg was retrieved but not in database
#  26%|██▌       | 236/922 [00:29<01:36,  7.11it/s][2026/06/16 19:39:11 hloc WARNING] Image db/2299.jpg was retrieved but not in database
#  26%|██▌       | 238/922 [00:29<01:29,  7.61it/s][2026/06/16 19:39:11 hloc WARNING] Image db/2299.jpg was retrieved but not in database
#  29%|██▉       | 266/922 [00:33<01:16,  8.60it/s][2026/06/16 19:39:15 hloc WARNING] Image db/2299.jpg was retrieved but not in database
#  33%|███▎      | 300/922 [00:38<01:03,  9.79it/s][2026/06/16 19:39:20 hloc WARNING] Image db/2303.jpg was retrieved but not in database
#  33%|███▎      | 307/922 [00:39<01:14,  8.23it/s][2026/06/16 19:39:21 hloc WARNING] Image db/2304.jpg was retrieved but not in database
#  35%|███▌      | 324/922 [00:41<01:00,  9.97it/s][2026/06/16 19:39:22 hloc WARNING] Image db/2367.jpg was retrieved but not in database
#  48%|████▊     | 439/922 [00:57<01:10,  6.88it/s][2026/06/16 19:39:39 hloc WARNING] Image db/2041.jpg was retrieved but not in database
#  50%|█████     | 461/922 [01:01<01:11,  6.47it/s][2026/06/16 19:39:43 hloc WARNING] Image db/1382.jpg was retrieved but not in database
#  51%|█████     | 469/922 [01:02<01:08,  6.58it/s][2026/06/16 19:39:44 hloc WARNING] Image db/2299.jpg was retrieved but not in database
#  52%|█████▏    | 475/922 [01:03<00:49,  8.95it/s][2026/06/16 19:39:44 hloc WARNING] Image db/2304.jpg was retrieved but not in database
# [2026/06/16 19:39:44 hloc WARNING] Image db/2303.jpg was retrieved but not in database
#  62%|██████▏   | 569/922 [01:16<00:54,  6.49it/s][2026/06/16 19:39:58 hloc WARNING] Image db/2221.jpg was retrieved but not in database
# [2026/06/16 19:39:58 hloc WARNING] Image db/2220.jpg was retrieved but not in database
#  74%|███████▍  | 683/922 [01:32<00:27,  8.57it/s][2026/06/16 19:40:14 hloc WARNING] Image db/2416.jpg was retrieved but not in database
#  74%|███████▍  | 685/922 [01:33<00:23,  9.89it/s][2026/06/16 19:40:15 hloc WARNING] Image db/2419.jpg was retrieved but not in database
# [2026/06/16 19:40:15 hloc WARNING] Image db/3780.jpg was retrieved but not in database
#  77%|███████▋  | 706/922 [01:36<00:26,  8.11it/s][2026/06/16 19:40:17 hloc WARNING] Image db/2625.jpg was retrieved but not in database
# [2026/06/16 19:40:17 hloc WARNING] Image db/2626.jpg was retrieved but not in database
#  80%|████████  | 738/922 [01:39<00:23,  7.85it/s][2026/06/16 19:40:21 hloc WARNING] Image db/2395.jpg was retrieved but not in database
# [2026/06/16 19:40:21 hloc WARNING] Image db/2397.jpg was retrieved but not in database
#  82%|████████▏ | 756/922 [01:43<00:19,  8.66it/s][2026/06/16 19:40:25 hloc WARNING] Image db/4034.jpg was retrieved but not in database
#  83%|████████▎ | 763/922 [01:43<00:16,  9.37it/s][2026/06/16 19:40:25 hloc WARNING] Image db/3941.jpg was retrieved but not in database
#  90%|█████████ | 830/922 [01:52<00:11,  8.28it/s][2026/06/16 19:40:34 hloc WARNING] Image db/2304.jpg was retrieved but not in database
# [2026/06/16 19:40:34 hloc WARNING] Image db/2303.jpg was retrieved but not in database
#  92%|█████████▏| 846/922 [01:54<00:10,  7.17it/s][2026/06/16 19:40:36 hloc WARNING] Image db/2041.jpg was retrieved but not in database
#  94%|█████████▎| 864/922 [01:57<00:08,  6.68it/s][2026/06/16 19:40:38 hloc WARNING] Image db/2041.jpg was retrieved but not in database
# 100%|██████████| 922/922 [02:05<00:00,  7.33it/s]
# [2026/06/16 19:40:47 hloc INFO] Localized 922 / 922 images.
# [2026/06/16 19:40:47 hloc INFO] Writing poses to outputs/aachen/Aachen_hloc_sfd2+aliked-lightglue_netvlad20.txt...
# [2026/06/16 19:40:47 hloc INFO] Writing logs to outputs/aachen/Aachen_hloc_sfd2+aliked-lightglue_netvlad20.txt_logs.pkl...
# [2026/06/16 19:40:56 hloc INFO] Done!

# %% [markdown]
# ## Visualizing the SfM model
# We visualize some of the database images with their detected keypoints.

# %% [markdown]
# Color the keypoints by track length: red keypoints are observed many times, blue keypoints few.

# %%
visualization.visualize_sfm_2d(reconstruction, images, n=1, color_by="track_length")

# %% [markdown]
# Color the keypoints by visibility: blue if sucessfully triangulated, red if never matched.

# %%
visualization.visualize_sfm_2d(reconstruction, images, n=1, color_by="visibility")

# %% [markdown]
# Color the keypoints by triangulated depth: red keypoints are far away, blue keypoints are closer.

# %%
visualization.visualize_sfm_2d(reconstruction, images, n=1, color_by="depth")

# %% [markdown]
# ## Visualizing the localization
# We parse the localization logs and for each query image plot matches and inliers with a few database images.

# %%
visualization.visualize_loc(
    results, images, reconstruction, n=1, top_k_db=1, prefix="query/night", seed=2
)
