# %%
# %load_ext autoreload
# %autoreload 2

from pathlib import Path
from pprint import pformat

from hloc import (
    extract_features,
    match_features,
    pairs_from_covisibility,
    pairs_from_retrieval,
)
from hloc import colmap_from_nvm, triangulation, localize_sfm, visualization

# %%
import os
proxy = "http://10.77.8.70:8080/"
os.environ['http_proxy'] = proxy
os.environ['https_proxy'] = proxy
os.environ['HTTP_PROXY'] = proxy
os.environ['HTTPS_PROXY'] = proxy
print("Proxies configured.")
# Out:
# Proxies configured.

# %% [markdown]
# # Pipeline for outdoor day-night visual localization

# %% [markdown]
# ## Setup
# Here we declare the paths to the dataset, the reconstruction and localization outputs, and we choose the feature extractor and the matcher. You only need to download the [Aachen Day-Night dataset](https://www.visuallocalization.net/datasets/) and put it in `datasets/aachen/`, or change the path.

# %%
dataset = Path("datasets/aachen/")  # change this if your dataset is somewhere else
images = dataset / "images_upright/"

outputs = Path("outputs/aachen/")  # where everything will be saved
sfm_pairs = outputs / "pairs-db-covis20.txt"  # top 20 most covisible in SIFT model
loc_pairs = outputs / "pairs-query-netvlad20.txt"  # top 20 retrieved by NetVLAD
reference_sfm = outputs / "sfm_sift"  # the SfM model we will build
results = outputs / "Aachen_hloc_orb.txt"  # the result file

# list the standard configurations available
print(f"Configs for feature extractors:\n{pformat(extract_features.confs)}")
print(f"Configs for feature matchers:\n{pformat(match_features.confs)}")
# Out:
# Configs for feature extractors:
# {'aliked-n16': {'model': {'model_name': 'aliked-n16', 'name': 'aliked'},
#                 'output': 'feats-aliked-n16',
#                 'preprocessing': {'grayscale': False, 'resize_max': 1024}},
#  'd2net-ss': {'model': {'multiscale': False, 'name': 'd2net'},
#               'output': 'feats-d2net-ss',
#               'preprocessing': {'grayscale': False, 'resize_max': 1600}},
#  'dir': {'model': {'name': 'dir'},
#          'output': 'global-feats-dir',
#          'preprocessing': {'resize_max': 1024}},
#  'disk': {'model': {'max_keypoints': 5000, 'name': 'disk'},
#           'output': 'feats-disk',
#           'preprocessing': {'grayscale': False, 'resize_max': 1600}},
#  'megaloc': {'model': {'name': 'megaloc'},
#              'output': 'global-feats-megaloc',
#              'preprocessing': {'resize_max': 1024}},
#  'netvlad': {'model': {'name': 'netvlad'},
#              'output': 'global-feats-netvlad',
#              'preprocessing': {'resize_max': 1024}},
#  'openibl': {'model': {'name': 'openibl'},
#              'output': 'global-feats-openibl',
#              'preprocessing': {'resize_max': 1024}},
#  'orb': {'model': {'name': 'orb'},
#          'output': 'feats-orb',
#          'preprocessing': {'grayscale': True, 'resize_max': 1600}},
#  'r2d2': {'model': {'max_keypoints': 5000, 'name': 'r2d2'},
#           'output': 'feats-r2d2-n5000-r1024',
#           'preprocessing': {'grayscale': False, 'resize_max': 1024}},
#  'sift': {'model': {'name': 'dog'},
#           'output': 'feats-sift',
#           'preprocessing': {'grayscale': True, 'resize_max': 1600}},
#  'sosnet': {'model': {'descriptor': 'sosnet', 'name': 'dog'},
#             'output': 'feats-sosnet',
#             'preprocessing': {'grayscale': True, 'resize_max': 1600}},
#  'superpoint_aachen': {'model': {'max_keypoints': 4096,
#                                  'name': 'superpoint',
#                                  'nms_radius': 3},
#                        'output': 'feats-superpoint-n4096-r1024',
#                        'preprocessing': {'grayscale': True,
#                                          'resize_max': 1024}},
#  'superpoint_inloc': {'model': {'max_keypoints': 4096,
#                                 'name': 'superpoint',
#                                 'nms_radius': 4},
#                       'output': 'feats-superpoint-n4096-r1600',
#                       'preprocessing': {'grayscale': True, 'resize_max': 1600}},
#  'superpoint_max': {'model': {'max_keypoints': 4096,
#                               'name': 'superpoint',
#                               'nms_radius': 3},
#                     'output': 'feats-superpoint-n4096-rmax1600',
#                     'preprocessing': {'grayscale': True,
#                                       'resize_force': True,
#                                       'resize_max': 1600}}}
# Configs for feature matchers:
# {'NN-mutual': {'model': {'do_mutual_check': True, 'name': 'nearest_neighbor'},
#                'output': 'matches-NN-mutual'},
#  'NN-ratio': {'model': {'do_mutual_check': True,
#                         'name': 'nearest_neighbor',
#                         'ratio_threshold': 0.8},
#               'output': 'matches-NN-mutual-ratio.8'},
#  'NN-superpoint': {'model': {'distance_threshold': 0.7,
#                              'do_mutual_check': True,
#                              'name': 'nearest_neighbor'},
#                    'output': 'matches-NN-mutual-dist.7'},
#  'adalam': {'model': {'name': 'adalam'}, 'output': 'matches-adalam'},
#  'aliked+lightglue': {'model': {'features': 'aliked', 'name': 'lightglue'},
#                       'output': 'matches-aliked-lightglue'},
#  'disk+lightglue': {'model': {'features': 'disk', 'name': 'lightglue'},
#                     'output': 'matches-disk-lightglue'},
#  'orb': {'model': {'do_mutual_check': True, 'name': 'orb_match'},
#          'output': 'matches-orb'},
#  'superglue': {'model': {'name': 'superglue',
#                          'sinkhorn_iterations': 50,
#                          'weights': 'outdoor'},
#                'output': 'matches-superglue'},
#  'superglue-fast': {'model': {'name': 'superglue',
#                               'sinkhorn_iterations': 5,
#                               'weights': 'outdoor'},
#                     'output': 'matches-superglue-it5'},
#  'superpoint+lightglue': {'model': {'features': 'superpoint',
#                                     'name': 'lightglue'},
#                           'output': 'matches-superpoint-lightglue'}}

# %%
# pick one of the configurations for image retrieval, local feature extraction, and matching
# you can also simply write your own here!
retrieval_conf = extract_features.confs["netvlad"]
feature_conf = extract_features.confs["sift"]
matcher_conf = match_features.confs["NN-ratio"]

# %% [markdown]
# ## Extract local features for database and query images

# %%
features = extract_features.main(feature_conf, images, outputs)
# Out:
# [2026/06/16 23:52:00 hloc INFO] Extracting local features with configuration:
# {'model': {'name': 'dog'},
#  'output': 'feats-sift',
#  'preprocessing': {'grayscale': True, 'resize_max': 1600}}
# [2026/06/16 23:52:00 hloc INFO] Found 5426 images in root datasets/aachen/images_upright.
# [2026/06/16 23:52:02 hloc INFO] Skipping the extraction.

# %% [markdown]
# The function returns the path of the file in which all the extracted features are stored.

# %% [markdown]
# ## Generate pairs for the SfM reconstruction
# Instead of matching all database images exhaustively, we exploit the existing SIFT model to find which image pairs are the most covisible. We first convert the SIFT model from the NVM to the COLMAP format, and then do a covisiblity search, selecting the top 20 most covisibile neighbors for each image.

# %%
sift_sfm = outputs / "sfm_sift"

# pairs_from_covisibility.main(sift_sfm, sfm_pairs, num_matched=20)

# %% [markdown]
# ## Match the database images

# %%
sfm_matches = match_features.main(
    matcher_conf, sfm_pairs, feature_conf["output"], outputs
)
# Out:
# [2026/06/16 23:52:02 hloc INFO] Matching local features with configuration:
# {'model': {'do_mutual_check': True,
#            'name': 'nearest_neighbor',
#            'ratio_threshold': 0.8},
#  'output': 'matches-NN-mutual-ratio.8'}
# 100%|██████████| 56734/56734 [09:23<00:00, 100.71it/s]
# [2026/06/17 00:01:26 hloc INFO] Finished exporting matches.

# %% [markdown]
# The function returns the path of the file in which all the computed matches are stored.

# %% [markdown]
# ## Triangulate a new SfM model from the given poses
# We triangulate the sparse 3D pointcloud given the matches and the reference poses stored in the SIFT COLMAP model.

# %%
reconstruction = triangulation.main(
    reference_sfm, sift_sfm, images, sfm_pairs, features, sfm_matches
)
# Out:
# [2026/06/17 00:01:29 hloc WARNING] The database already exists, deleting it.
# [2026/06/17 00:01:29 hloc INFO] Importing features into the database...
# 100%|██████████| 4328/4328 [00:02<00:00, 2016.44it/s]
# [2026/06/17 00:01:32 hloc INFO] Importing matches into the database...
# 100%|██████████| 85515/85515 [00:32<00:00, 2630.23it/s]
# [2026/06/17 00:02:04 hloc INFO] Performing geometric verification of the matches...
# 100%|██████████| 4328/4328 [04:42<00:00, 15.32it/s]
# [2026/06/17 00:06:47 hloc INFO] mean/med/min/max valid matches 75.60/87.72/0.00/100.00%.
# [2026/06/17 00:06:47 hloc INFO] Running 3D triangulation...
# [2026/06/17 00:09:13 hloc INFO] Finished the triangulation with statistics:
# Reconstruction:
# 	num_rigs = 4328
# 	num_cameras = 4328
# 	num_frames = 4328
# 	num_reg_frames = 4328
# 	num_images = 4328
# 	num_points3D = 739151
# 	num_observations = 4803557
# 	mean_track_length = 6.49875
# 	mean_observations_per_image = 1109.88
# 	mean_reprojection_error = 0.778691

# %% [markdown]
# ## Find image pairs via image retrieval
# We extract global descriptors with NetVLAD and find for each image the $k$ most similar ones. A larger $k$ improves the robustness of the localization for difficult queries but makes the matching more expensive. Using $k{=}10{-}20$ is generally a good tradeoff but $k{=}50$ gives the best results for the Aachen Day-Night dataset.

# %%
global_descriptors = extract_features.main(retrieval_conf, images, outputs)
pairs_from_retrieval.main(
    global_descriptors, loc_pairs, num_matched=20, db_prefix="db", query_prefix="query"
)
# Out:
# [2026/06/17 00:09:13 hloc INFO] Extracting local features with configuration:
# {'model': {'name': 'netvlad'},
#  'output': 'global-feats-netvlad',
#  'preprocessing': {'resize_max': 1024}}
# [2026/06/17 00:09:13 hloc INFO] Found 5426 images in root datasets/aachen/images_upright.
# [2026/06/17 00:09:14 hloc INFO] Skipping the extraction.
# [2026/06/17 00:09:14 hloc INFO] Extracting image pairs from a retrieval database.
# [2026/06/17 00:09:17 hloc INFO] Found 18940 pairs.

# %% [markdown]
# ## Match the query images

# %%
loc_matches = match_features.main(
    matcher_conf, loc_pairs, feature_conf["output"], outputs
)
# Out:
# [2026/06/17 00:09:17 hloc INFO] Matching local features with configuration:
# {'model': {'do_mutual_check': True,
#            'name': 'nearest_neighbor',
#            'ratio_threshold': 0.8},
#  'output': 'matches-NN-mutual-ratio.8'}
# 100%|██████████| 18940/18940 [03:01<00:00, 104.19it/s]
# [2026/06/17 00:12:19 hloc INFO] Finished exporting matches.

# %% [markdown]
# ## Localize!
# Perform hierarchical localization using the precomputed retrieval and matches. The file `Aachen_hloc_superpoint+superglue_netvlad50.txt` will contain the estimated query poses. Have a look at `Aachen_hloc_superpoint+superglue_netvlad50.txt_logs.pkl` to analyze some statistics and find failure cases.

# %%
localize_sfm.main(
    reconstruction,
    dataset / "queries/*_time_queries_with_intrinsics.txt",
    loc_pairs,
    features,
    loc_matches,
    results,
    covisibility_clustering=False,
)  # not required with SuperPoint+SuperGlue
# Out:
# [2026/06/17 00:12:19 hloc.utils.parsers INFO] Imported 98 images from night_time_queries_with_intrinsics.txt
# [2026/06/17 00:12:19 hloc.utils.parsers INFO] Imported 824 images from day_time_queries_with_intrinsics.txt
# [2026/06/17 00:12:19 hloc INFO] Reading the 3D model...
# [2026/06/17 00:12:19 hloc INFO] Starting localization...
#   2%|▏         | 21/922 [00:01<01:09, 13.00it/s][2026/06/17 00:12:20 hloc WARNING] Image db/2418.jpg was retrieved but not in database
#   4%|▍         | 39/922 [00:03<01:16, 11.51it/s][2026/06/17 00:12:22 hloc WARNING] Image db/2416.jpg was retrieved but not in database
#   6%|▌         | 53/922 [00:04<01:20, 10.77it/s][2026/06/17 00:12:23 hloc WARNING] Image db/3945.jpg was retrieved but not in database
#   6%|▌         | 55/922 [00:04<01:15, 11.48it/s][2026/06/17 00:12:23 hloc WARNING] Image db/2625.jpg was retrieved but not in database
#   8%|▊         | 71/922 [00:05<01:11, 11.95it/s][2026/06/17 00:12:25 hloc WARNING] Image db/3940.jpg was retrieved but not in database
# [2026/06/17 00:12:25 hloc WARNING] Image db/3807.jpg was retrieved but not in database
#  10%|█         | 95/922 [00:07<01:07, 12.33it/s][2026/06/17 00:12:26 hloc WARNING] Image db/3932.jpg was retrieved but not in database
# [2026/06/17 00:12:27 hloc WARNING] Image db/3785.jpg was retrieved but not in database
#  14%|█▍        | 127/922 [00:10<01:07, 11.76it/s][2026/06/17 00:12:29 hloc WARNING] Image db/2395.jpg was retrieved but not in database
# [2026/06/17 00:12:29 hloc WARNING] Image db/2402.jpg was retrieved but not in database
#  15%|█▍        | 137/922 [00:11<01:22,  9.53it/s][2026/06/17 00:12:30 hloc WARNING] Image db/2420.jpg was retrieved but not in database
# [2026/06/17 00:12:30 hloc WARNING] Image db/2421.jpg was retrieved but not in database
#  21%|██        | 191/922 [00:16<01:07, 10.84it/s][2026/06/17 00:12:35 hloc WARNING] Image db/1382.jpg was retrieved but not in database
#  26%|██▌       | 237/922 [00:20<01:02, 10.88it/s][2026/06/17 00:12:39 hloc WARNING] Image db/2299.jpg was retrieved but not in database
# [2026/06/17 00:12:39 hloc WARNING] Image db/2299.jpg was retrieved but not in database
#  29%|██▊       | 265/922 [00:23<01:00, 10.90it/s][2026/06/17 00:12:42 hloc WARNING] Image db/2299.jpg was retrieved but not in database
#  33%|███▎      | 301/922 [00:26<00:47, 13.02it/s][2026/06/17 00:12:45 hloc WARNING] Image db/2303.jpg was retrieved but not in database
#  33%|███▎      | 307/922 [00:26<00:50, 12.22it/s][2026/06/17 00:12:45 hloc WARNING] Image db/2304.jpg was retrieved but not in database
#  35%|███▌      | 323/922 [00:28<00:49, 12.18it/s][2026/06/17 00:12:47 hloc WARNING] Image db/2367.jpg was retrieved but not in database
#  48%|████▊     | 439/922 [00:38<00:45, 10.51it/s][2026/06/17 00:12:57 hloc WARNING] Image db/2041.jpg was retrieved but not in database
#  50%|█████     | 461/922 [00:40<00:43, 10.53it/s][2026/06/17 00:12:59 hloc WARNING] Image db/1382.jpg was retrieved but not in database
#  51%|█████     | 469/922 [00:41<00:40, 11.09it/s][2026/06/17 00:13:00 hloc WARNING] Image db/2299.jpg was retrieved but not in database
#  52%|█████▏    | 475/922 [00:41<00:36, 12.39it/s][2026/06/17 00:13:00 hloc WARNING] Image db/2304.jpg was retrieved but not in database
# [2026/06/17 00:13:00 hloc WARNING] Image db/2303.jpg was retrieved but not in database
#  62%|██████▏   | 569/922 [00:49<00:32, 10.76it/s][2026/06/17 00:13:08 hloc WARNING] Image db/2221.jpg was retrieved but not in database
# [2026/06/17 00:13:08 hloc WARNING] Image db/2220.jpg was retrieved but not in database
#  74%|███████▍  | 682/922 [01:00<00:19, 12.41it/s][2026/06/17 00:13:19 hloc WARNING] Image db/2416.jpg was retrieved but not in database
#  74%|███████▍  | 686/922 [01:00<00:19, 11.99it/s][2026/06/17 00:13:19 hloc WARNING] Image db/2419.jpg was retrieved but not in database
# [2026/06/17 00:13:19 hloc WARNING] Image db/3780.jpg was retrieved but not in database
#  77%|███████▋  | 706/922 [01:02<00:17, 12.47it/s][2026/06/17 00:13:21 hloc WARNING] Image db/2625.jpg was retrieved but not in database
# [2026/06/17 00:13:21 hloc WARNING] Image db/2626.jpg was retrieved but not in database
#  80%|████████  | 738/922 [01:05<00:17, 10.23it/s][2026/06/17 00:13:24 hloc WARNING] Image db/2395.jpg was retrieved but not in database
# [2026/06/17 00:13:24 hloc WARNING] Image db/2397.jpg was retrieved but not in database
#  82%|████████▏ | 756/922 [01:06<00:13, 11.98it/s][2026/06/17 00:13:25 hloc WARNING] Image db/4034.jpg was retrieved but not in database
#  83%|████████▎ | 764/922 [01:07<00:14, 10.86it/s][2026/06/17 00:13:26 hloc WARNING] Image db/3941.jpg was retrieved but not in database
#  90%|█████████ | 830/922 [01:13<00:08, 11.23it/s][2026/06/17 00:13:32 hloc WARNING] Image db/2304.jpg was retrieved but not in database
# [2026/06/17 00:13:32 hloc WARNING] Image db/2303.jpg was retrieved but not in database
#  92%|█████████▏| 846/922 [01:14<00:06, 11.86it/s][2026/06/17 00:13:33 hloc WARNING] Image db/2041.jpg was retrieved but not in database
#  94%|█████████▎| 864/922 [01:16<00:05, 10.73it/s][2026/06/17 00:13:35 hloc WARNING] Image db/2041.jpg was retrieved but not in database
# 100%|██████████| 922/922 [01:21<00:00, 11.37it/s]
# [2026/06/17 00:13:40 hloc INFO] Localized 922 / 922 images.
# [2026/06/17 00:13:40 hloc INFO] Writing poses to outputs/aachen/Aachen_hloc_orb.txt...
# [2026/06/17 00:13:40 hloc INFO] Writing logs to outputs/aachen/Aachen_hloc_orb.txt_logs.pkl...
# [2026/06/17 00:13:41 hloc INFO] Done!

# %% [markdown]
# ## Visualizing the SfM model
# We visualize some of the database images with their detected keypoints.

# %% [markdown]
# Color the keypoints by track length: red keypoints are observed many times, blue keypoints few.

# %%
visualization.visualize_sfm_2d(reconstruction, images, n=1, color_by="track_length")

# %% [markdown]
# Color the keypoints by visibility: blue if sucessfully triangulated, red if never matched.

# %%
visualization.visualize_sfm_2d(reconstruction, images, n=1, color_by="visibility")

# %% [markdown]
# Color the keypoints by triangulated depth: red keypoints are far away, blue keypoints are closer.

# %%
visualization.visualize_sfm_2d(reconstruction, images, n=1, color_by="depth")

# %% [markdown]
# ## Visualizing the localization
# We parse the localization logs and for each query image plot matches and inliers with a few database images.

# %%
visualization.visualize_loc(
    results, images, reconstruction, n=1, top_k_db=1, prefix="query/night", seed=2
)
